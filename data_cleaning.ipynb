# %%
import pandas as pd

# %%
file_path = 'clean_data.csv'

# %%
raw_data_df = pd.read_csv(file_path)
raw_data_df.head()
# Out:
#                                      CRASH_RECORD_ID              CRASH_DATE  \
# 0  23a79931ef555d54118f64dc9be2cf2dbf59636ce253f7...  09/05/2023 07:05:00 PM
# 1  2675c13fd0f474d730a5b780968b3cafc7c12d7adb661f...  09/22/2023 06:45:00 PM
# 2  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4...  07/29/2023 02:45:00 PM
# 3  7ebf015016f83d09b321afd671a836d6b148330535d5df...  08/09/2023 11:00:00 PM
# 4  6c1659069e9c6285a650e70d6f9b574ed5f64c12888479...  08/18/2023 12:50:00 PM
#
#    POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE WEATHER_CONDITION  \
# 0                  30         TRAFFIC SIGNAL             CLEAR
# 1                  50            NO CONTROLS             CLEAR
# 2                  30         TRAFFIC SIGNAL             CLEAR
# 3                  30            NO CONTROLS             CLEAR
# 4                  15                  OTHER             CLEAR
#
#        LIGHTING_CONDITION          FIRST_CRASH_TYPE ROADWAY_SURFACE_COND  \
# ...

# %%
raw_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 813559 entries, 0 to 813558
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   CRASH_RECORD_ID          813559 non-null  object
#  1   CRASH_DATE               813559 non-null  object
#  2   POSTED_SPEED_LIMIT       813559 non-null  int64
#  3   TRAFFIC_CONTROL_DEVICE   813559 non-null  object
#  4   WEATHER_CONDITION        813559 non-null  object
#  5   LIGHTING_CONDITION       813559 non-null  object
#  6   FIRST_CRASH_TYPE         813559 non-null  object
#  7   ROADWAY_SURFACE_COND     813559 non-null  object
#  8   CRASH_TYPE               813559 non-null  object
#  9   DAMAGE                   813559 non-null  object
#  10  PRIM_CONTRIBUTORY_CAUSE  813559 non-null  object
#  11  NUM_UNITS                813559 non-null  int64
#  12  MOST_SEVERE_INJURY       811773 non-null  object
# ...

# %%
columns_to_drop = ['CRASH_DATE_EST_I', 'DEVICE_CONDITION', 'TRAFFICWAY_TYPE', 'LANE_CNT', 'ALIGNMENT', 'ROAD_DEFECT', 'REPORT_TYPE', 'INTERSECTION_RELATED_I', 'NOT_RIGHT_OF_WAY_I', 'HIT_AND_RUN_I', 'DATE_POLICE_NOTIFIED', 'SEC_CONTRIBUTORY_CAUSE', 'STREET_NO', 'STREET_DIRECTION', 'STREET_NAME', 'BEAT_OF_OCCURRENCE', 'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'DOORING_I', 'WORK_ZONE_I', 'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I', 'INJURIES_NON_INCAPACITATING', 'INJURIES_REPORTED_NOT_EVIDENT', 'INJURIES_NO_INDICATION', 'INJURIES_UNKNOWN', 'LOCATION']

# %%
#raw_data_df = raw_data_df.drop(columns=columns_to_drop)
len(raw_data_df)
# Out:
# 813559

# %%
raw_data_df.head()
# Out:
#                                      CRASH_RECORD_ID              CRASH_DATE  \
# 0  23a79931ef555d54118f64dc9be2cf2dbf59636ce253f7...  09/05/2023 07:05:00 PM
# 1  2675c13fd0f474d730a5b780968b3cafc7c12d7adb661f...  09/22/2023 06:45:00 PM
# 2  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4...  07/29/2023 02:45:00 PM
# 3  7ebf015016f83d09b321afd671a836d6b148330535d5df...  08/09/2023 11:00:00 PM
# 4  6c1659069e9c6285a650e70d6f9b574ed5f64c12888479...  08/18/2023 12:50:00 PM
#
#    POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE WEATHER_CONDITION  \
# 0                  30         TRAFFIC SIGNAL             CLEAR
# 1                  50            NO CONTROLS             CLEAR
# 2                  30         TRAFFIC SIGNAL             CLEAR
# 3                  30            NO CONTROLS             CLEAR
# 4                  15                  OTHER             CLEAR
#
#        LIGHTING_CONDITION          FIRST_CRASH_TYPE ROADWAY_SURFACE_COND  \
# ...

# %%
raw_data_df['CRASH_DATE'] = pd.to_datetime(raw_data_df['CRASH_DATE'], format='%m/%d/%Y %I:%M:%S %p')
raw_data_df.head()
# Out:
#                                      CRASH_RECORD_ID          CRASH_DATE  \
# 0  23a79931ef555d54118f64dc9be2cf2dbf59636ce253f7... 2023-09-05 19:05:00
# 1  2675c13fd0f474d730a5b780968b3cafc7c12d7adb661f... 2023-09-22 18:45:00
# 2  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4... 2023-07-29 14:45:00
# 3  7ebf015016f83d09b321afd671a836d6b148330535d5df... 2023-08-09 23:00:00
# 4  6c1659069e9c6285a650e70d6f9b574ed5f64c12888479... 2023-08-18 12:50:00
#
#    POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE WEATHER_CONDITION  \
# 0                  30         TRAFFIC SIGNAL             CLEAR
# 1                  50            NO CONTROLS             CLEAR
# 2                  30         TRAFFIC SIGNAL             CLEAR
# 3                  30            NO CONTROLS             CLEAR
# 4                  15                  OTHER             CLEAR
#
#        LIGHTING_CONDITION          FIRST_CRASH_TYPE ROADWAY_SURFACE_COND  \
# ...

# %%
raw_data_df = raw_data_df[raw_data_df['CRASH_DATE'].dt.year > 2021]
raw_data_df.head()
# Out:
#                                      CRASH_RECORD_ID          CRASH_DATE  \
# 0  23a79931ef555d54118f64dc9be2cf2dbf59636ce253f7... 2023-09-05 19:05:00
# 1  2675c13fd0f474d730a5b780968b3cafc7c12d7adb661f... 2023-09-22 18:45:00
# 2  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4... 2023-07-29 14:45:00
# 3  7ebf015016f83d09b321afd671a836d6b148330535d5df... 2023-08-09 23:00:00
# 4  6c1659069e9c6285a650e70d6f9b574ed5f64c12888479... 2023-08-18 12:50:00
#
#    POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE WEATHER_CONDITION  \
# 0                  30         TRAFFIC SIGNAL             CLEAR
# 1                  50            NO CONTROLS             CLEAR
# 2                  30         TRAFFIC SIGNAL             CLEAR
# 3                  30            NO CONTROLS             CLEAR
# 4                  15                  OTHER             CLEAR
#
#        LIGHTING_CONDITION          FIRST_CRASH_TYPE ROADWAY_SURFACE_COND  \
# ...

# %%
len(raw_data_df)
# Out:
# 238071

# %%
raw_data_df.to_csv('2022-2023.csv', index=False)
