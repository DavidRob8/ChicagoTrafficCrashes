# %%
import pandas as pd

# %%
file_path = '2022-2023.csv'

# %%
raw_data_df = pd.read_csv(file_path)
raw_data_df.head()
# Out:
#                                      CRASH_RECORD_ID       CRASH_DATE  \
# 0  23a79931ef555d54118f64dc9be2cf2dbf59636ce253f7...   9/5/2023 19:05
# 1  2675c13fd0f474d730a5b780968b3cafc7c12d7adb661f...  9/22/2023 18:45
# 2  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4...  7/29/2023 14:45
# 3  7ebf015016f83d09b321afd671a836d6b148330535d5df...   8/9/2023 23:00
# 4  6c1659069e9c6285a650e70d6f9b574ed5f64c12888479...  8/18/2023 12:50
#
#      Weekday  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE WEATHER_CONDITION  \
# 0    Tuesday                  30         TRAFFIC SIGNAL             CLEAR
# 1     Friday                  50            NO CONTROLS             CLEAR
# 2   Saturday                  30         TRAFFIC SIGNAL             CLEAR
# 3  Wednesday                  30            NO CONTROLS             CLEAR
# 4     Friday                  15                  OTHER             CLEAR
#
#        LIGHTING_CONDITION          FIRST_CRASH_TYPE ROADWAY_SURFACE_COND  \
# 0                    DUSK                     ANGLE                  DRY
# 1  DARKNESS, LIGHTED ROAD                  REAR END                  DRY
# 2                DAYLIGHT      PARKED MOTOR VEHICLE                  DRY
# 3  DARKNESS, LIGHTED ROAD  SIDESWIPE SAME DIRECTION                  DRY
# 4                DAYLIGHT                  REAR END                  DRY
#
#                          CRASH_TYPE  ...        MOST_SEVERE_INJURY  \
# 0  INJURY AND / OR TOW DUE TO CRASH  ...     INCAPACITATING INJURY
# 1            NO INJURY / DRIVE AWAY  ...   NO INDICATION OF INJURY
# 2            NO INJURY / DRIVE AWAY  ...   NO INDICATION OF INJURY
# 3            NO INJURY / DRIVE AWAY  ...   NO INDICATION OF INJURY
# 4  INJURY AND / OR TOW DUE TO CRASH  ...  NONINCAPACITATING INJURY
#
#   INJURIES_TOTAL  INJURIES_FATAL INJURIES_INCAPACITATING  CRASH_HOUR  \
# 0            3.0             0.0                     1.0          19
# 1            0.0             0.0                     0.0          18
# 2            0.0             0.0                     0.0          14
# 3            0.0             0.0                     0.0          23
# 4            1.0             0.0                     0.0          12
#
#    CRASH_DAY_OF_WEEK  CRASH_MONTH  LATITUDE  LONGITUDE  \
# 0                  3            9       NaN        NaN
# 1                  6            9       NaN        NaN
# 2                  7            7  41.85412 -87.665902
# 3                  4            8       NaN        NaN
# 4                  6            8       NaN        NaN
#
#                          CRASH_TIME
# 0  ['09/05/2023', '07:05:00', 'PM']
# 1  ['09/22/2023', '06:45:00', 'PM']
# 2  ['07/29/2023', '02:45:00', 'PM']
# 3  ['08/09/2023', '11:00:00', 'PM']
# 4  ['08/18/2023', '12:50:00', 'PM']
#
# [5 rows x 23 columns]

# %%
raw_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238071 entries, 0 to 238070
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   CRASH_RECORD_ID          238071 non-null  object
#  1   CRASH_DATE               238071 non-null  object
#  2   Weekday                  238071 non-null  object
#  3   POSTED_SPEED_LIMIT       238071 non-null  int64
#  4   TRAFFIC_CONTROL_DEVICE   238071 non-null  object
#  5   WEATHER_CONDITION        238071 non-null  object
#  6   LIGHTING_CONDITION       238071 non-null  object
#  7   FIRST_CRASH_TYPE         238071 non-null  object
#  8   ROADWAY_SURFACE_COND     238071 non-null  object
#  9   CRASH_TYPE               238071 non-null  object
#  10  DAMAGE                   238071 non-null  object
#  11  PRIM_CONTRIBUTORY_CAUSE  238071 non-null  object
#  12  NUM_UNITS                238071 non-null  int64
#  13  MOST_SEVERE_INJURY       237482 non-null  object
#  14  INJURIES_TOTAL           237483 non-null  float64
#  15  INJURIES_FATAL           237483 non-null  float64
#  16  INJURIES_INCAPACITATING  237483 non-null  float64
#  17  CRASH_HOUR               238071 non-null  int64
#  18  CRASH_DAY_OF_WEEK        238071 non-null  int64
#  19  CRASH_MONTH              238071 non-null  int64
#  20  LATITUDE                 235887 non-null  float64
#  21  LONGITUDE                235887 non-null  float64
#  22  CRASH_TIME               238071 non-null  object
# dtypes: float64(5), int64(5), object(13)
# memory usage: 41.8+ MB

# %%
columns_to_drop = ['CRASH_DATE_EST_I', 'DEVICE_CONDITION', 'TRAFFICWAY_TYPE', 'LANE_CNT', 'ALIGNMENT', 'ROAD_DEFECT', 'REPORT_TYPE', 'INTERSECTION_RELATED_I', 'NOT_RIGHT_OF_WAY_I', 'HIT_AND_RUN_I', 'DATE_POLICE_NOTIFIED', 'SEC_CONTRIBUTORY_CAUSE', 'STREET_NO', 'STREET_DIRECTION', 'STREET_NAME', 'BEAT_OF_OCCURRENCE', 'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'DOORING_I', 'WORK_ZONE_I', 'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I', 'INJURIES_NON_INCAPACITATING', 'INJURIES_REPORTED_NOT_EVIDENT', 'INJURIES_NO_INDICATION', 'INJURIES_UNKNOWN', 'LOCATION']

# %%
#raw_data_df = raw_data_df.drop(columns=columns_to_drop)
len(raw_data_df)
# Out:
# 238071

# %%
raw_data_df.head()
# Out:
#                                      CRASH_RECORD_ID       CRASH_DATE  \
# 0  23a79931ef555d54118f64dc9be2cf2dbf59636ce253f7...   9/5/2023 19:05
# 1  2675c13fd0f474d730a5b780968b3cafc7c12d7adb661f...  9/22/2023 18:45
# 2  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4...  7/29/2023 14:45
# 3  7ebf015016f83d09b321afd671a836d6b148330535d5df...   8/9/2023 23:00
# 4  6c1659069e9c6285a650e70d6f9b574ed5f64c12888479...  8/18/2023 12:50
#
#      Weekday  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE WEATHER_CONDITION  \
# 0    Tuesday                  30         TRAFFIC SIGNAL             CLEAR
# 1     Friday                  50            NO CONTROLS             CLEAR
# 2   Saturday                  30         TRAFFIC SIGNAL             CLEAR
# 3  Wednesday                  30            NO CONTROLS             CLEAR
# 4     Friday                  15                  OTHER             CLEAR
#
#        LIGHTING_CONDITION          FIRST_CRASH_TYPE ROADWAY_SURFACE_COND  \
# 0                    DUSK                     ANGLE                  DRY
# 1  DARKNESS, LIGHTED ROAD                  REAR END                  DRY
# 2                DAYLIGHT      PARKED MOTOR VEHICLE                  DRY
# 3  DARKNESS, LIGHTED ROAD  SIDESWIPE SAME DIRECTION                  DRY
# 4                DAYLIGHT                  REAR END                  DRY
#
#                          CRASH_TYPE  ...        MOST_SEVERE_INJURY  \
# 0  INJURY AND / OR TOW DUE TO CRASH  ...     INCAPACITATING INJURY
# 1            NO INJURY / DRIVE AWAY  ...   NO INDICATION OF INJURY
# 2            NO INJURY / DRIVE AWAY  ...   NO INDICATION OF INJURY
# 3            NO INJURY / DRIVE AWAY  ...   NO INDICATION OF INJURY
# 4  INJURY AND / OR TOW DUE TO CRASH  ...  NONINCAPACITATING INJURY
#
#   INJURIES_TOTAL  INJURIES_FATAL INJURIES_INCAPACITATING  CRASH_HOUR  \
# 0            3.0             0.0                     1.0          19
# 1            0.0             0.0                     0.0          18
# 2            0.0             0.0                     0.0          14
# 3            0.0             0.0                     0.0          23
# 4            1.0             0.0                     0.0          12
#
#    CRASH_DAY_OF_WEEK  CRASH_MONTH  LATITUDE  LONGITUDE  \
# 0                  3            9       NaN        NaN
# 1                  6            9       NaN        NaN
# 2                  7            7  41.85412 -87.665902
# 3                  4            8       NaN        NaN
# 4                  6            8       NaN        NaN
#
#                          CRASH_TIME
# 0  ['09/05/2023', '07:05:00', 'PM']
# 1  ['09/22/2023', '06:45:00', 'PM']
# 2  ['07/29/2023', '02:45:00', 'PM']
# 3  ['08/09/2023', '11:00:00', 'PM']
# 4  ['08/18/2023', '12:50:00', 'PM']
#
# [5 rows x 23 columns]

# %%
raw_data_df['CRASH_DATE'] = pd.to_datetime(raw_data_df['CRASH_DATE'], format='%m/%d/%Y %H:%M')
raw_data_df.head()
# Out:
#                                      CRASH_RECORD_ID          CRASH_DATE  \
# 0  23a79931ef555d54118f64dc9be2cf2dbf59636ce253f7... 2023-09-05 19:05:00
# 1  2675c13fd0f474d730a5b780968b3cafc7c12d7adb661f... 2023-09-22 18:45:00
# 2  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4... 2023-07-29 14:45:00
# 3  7ebf015016f83d09b321afd671a836d6b148330535d5df... 2023-08-09 23:00:00
# 4  6c1659069e9c6285a650e70d6f9b574ed5f64c12888479... 2023-08-18 12:50:00
#
#      Weekday  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE WEATHER_CONDITION  \
# 0    Tuesday                  30         TRAFFIC SIGNAL             CLEAR
# 1     Friday                  50            NO CONTROLS             CLEAR
# 2   Saturday                  30         TRAFFIC SIGNAL             CLEAR
# 3  Wednesday                  30            NO CONTROLS             CLEAR
# 4     Friday                  15                  OTHER             CLEAR
#
#        LIGHTING_CONDITION          FIRST_CRASH_TYPE ROADWAY_SURFACE_COND  \
# 0                    DUSK                     ANGLE                  DRY
# 1  DARKNESS, LIGHTED ROAD                  REAR END                  DRY
# 2                DAYLIGHT      PARKED MOTOR VEHICLE                  DRY
# 3  DARKNESS, LIGHTED ROAD  SIDESWIPE SAME DIRECTION                  DRY
# 4                DAYLIGHT                  REAR END                  DRY
#
#                          CRASH_TYPE  ...        MOST_SEVERE_INJURY  \
# 0  INJURY AND / OR TOW DUE TO CRASH  ...     INCAPACITATING INJURY
# 1            NO INJURY / DRIVE AWAY  ...   NO INDICATION OF INJURY
# 2            NO INJURY / DRIVE AWAY  ...   NO INDICATION OF INJURY
# 3            NO INJURY / DRIVE AWAY  ...   NO INDICATION OF INJURY
# 4  INJURY AND / OR TOW DUE TO CRASH  ...  NONINCAPACITATING INJURY
#
#   INJURIES_TOTAL  INJURIES_FATAL INJURIES_INCAPACITATING  CRASH_HOUR  \
# 0            3.0             0.0                     1.0          19
# 1            0.0             0.0                     0.0          18
# 2            0.0             0.0                     0.0          14
# 3            0.0             0.0                     0.0          23
# 4            1.0             0.0                     0.0          12
#
#    CRASH_DAY_OF_WEEK  CRASH_MONTH  LATITUDE  LONGITUDE  \
# 0                  3            9       NaN        NaN
# 1                  6            9       NaN        NaN
# 2                  7            7  41.85412 -87.665902
# 3                  4            8       NaN        NaN
# 4                  6            8       NaN        NaN
#
#                          CRASH_TIME
# 0  ['09/05/2023', '07:05:00', 'PM']
# 1  ['09/22/2023', '06:45:00', 'PM']
# 2  ['07/29/2023', '02:45:00', 'PM']
# 3  ['08/09/2023', '11:00:00', 'PM']
# 4  ['08/18/2023', '12:50:00', 'PM']
#
# [5 rows x 23 columns]

# %%
raw_data_df = raw_data_df[(raw_data_df['CRASH_DATE'].dt.year == 2022) | (raw_data_df['CRASH_DATE'].dt.year == 2023)]
raw_data_df.head()
# Out:
#                                      CRASH_RECORD_ID          CRASH_DATE  \
# 0  23a79931ef555d54118f64dc9be2cf2dbf59636ce253f7... 2023-09-05 19:05:00
# 1  2675c13fd0f474d730a5b780968b3cafc7c12d7adb661f... 2023-09-22 18:45:00
# 2  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4... 2023-07-29 14:45:00
# 3  7ebf015016f83d09b321afd671a836d6b148330535d5df... 2023-08-09 23:00:00
# 4  6c1659069e9c6285a650e70d6f9b574ed5f64c12888479... 2023-08-18 12:50:00
#
#      Weekday  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE WEATHER_CONDITION  \
# 0    Tuesday                  30         TRAFFIC SIGNAL             CLEAR
# 1     Friday                  50            NO CONTROLS             CLEAR
# 2   Saturday                  30         TRAFFIC SIGNAL             CLEAR
# 3  Wednesday                  30            NO CONTROLS             CLEAR
# 4     Friday                  15                  OTHER             CLEAR
#
#        LIGHTING_CONDITION          FIRST_CRASH_TYPE ROADWAY_SURFACE_COND  \
# 0                    DUSK                     ANGLE                  DRY
# 1  DARKNESS, LIGHTED ROAD                  REAR END                  DRY
# 2                DAYLIGHT      PARKED MOTOR VEHICLE                  DRY
# 3  DARKNESS, LIGHTED ROAD  SIDESWIPE SAME DIRECTION                  DRY
# 4                DAYLIGHT                  REAR END                  DRY
#
#                          CRASH_TYPE  ...        MOST_SEVERE_INJURY  \
# 0  INJURY AND / OR TOW DUE TO CRASH  ...     INCAPACITATING INJURY
# 1            NO INJURY / DRIVE AWAY  ...   NO INDICATION OF INJURY
# 2            NO INJURY / DRIVE AWAY  ...   NO INDICATION OF INJURY
# 3            NO INJURY / DRIVE AWAY  ...   NO INDICATION OF INJURY
# 4  INJURY AND / OR TOW DUE TO CRASH  ...  NONINCAPACITATING INJURY
#
#   INJURIES_TOTAL  INJURIES_FATAL INJURIES_INCAPACITATING  CRASH_HOUR  \
# 0            3.0             0.0                     1.0          19
# 1            0.0             0.0                     0.0          18
# 2            0.0             0.0                     0.0          14
# 3            0.0             0.0                     0.0          23
# 4            1.0             0.0                     0.0          12
#
#    CRASH_DAY_OF_WEEK  CRASH_MONTH  LATITUDE  LONGITUDE  \
# 0                  3            9       NaN        NaN
# 1                  6            9       NaN        NaN
# 2                  7            7  41.85412 -87.665902
# 3                  4            8       NaN        NaN
# 4                  6            8       NaN        NaN
#
#                          CRASH_TIME
# 0  ['09/05/2023', '07:05:00', 'PM']
# 1  ['09/22/2023', '06:45:00', 'PM']
# 2  ['07/29/2023', '02:45:00', 'PM']
# 3  ['08/09/2023', '11:00:00', 'PM']
# 4  ['08/18/2023', '12:50:00', 'PM']
#
# [5 rows x 23 columns]

# %%
len(raw_data_df)
# Out:
# 219125

# %%
sorted_raw_data_df = raw_data_df.sort_values(by='CRASH_DATE', ascending=False)
sorted_raw_data_df.head()
# Out:
#                                           CRASH_RECORD_ID          CRASH_DATE  \
# 151003  9f33be6bff3923ab957886c9cafc6c097322c46d385f1b... 2023-12-31 23:50:00
# 42328   2548b7bae8e53a941f28d18ccbe0f444cc9bf3b2c3eaa1... 2023-12-31 23:30:00
# 158930  a83a8b4b3c0f2ae287fabeeb70066a1662ee311b394bff... 2023-12-31 23:30:00
# 226793  f3be89d0340e4c18cc21acf686ea99ba028fcbff311460... 2023-12-31 23:29:00
# 51751   2fd2bc0bc3f724fc9580cdfa77446aec2d59226b917b10... 2023-12-31 23:25:00
#
#        Weekday  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE WEATHER_CONDITION  \
# 151003  Sunday                  30            NO CONTROLS              RAIN
# 42328   Sunday                   5            NO CONTROLS           UNKNOWN
# 158930  Sunday                  25            NO CONTROLS             CLEAR
# 226793  Sunday                  30            NO CONTROLS             CLEAR
# 51751   Sunday                  30         TRAFFIC SIGNAL             CLEAR
#
#             LIGHTING_CONDITION          FIRST_CRASH_TYPE ROADWAY_SURFACE_COND  \
# 151003  DARKNESS, LIGHTED ROAD      PARKED MOTOR VEHICLE                  WET
# 42328                  UNKNOWN      PARKED MOTOR VEHICLE              UNKNOWN
# 158930  DARKNESS, LIGHTED ROAD      PARKED MOTOR VEHICLE                  DRY
# 226793                DARKNESS              FIXED OBJECT                  DRY
# 51751   DARKNESS, LIGHTED ROAD  SIDESWIPE SAME DIRECTION                  DRY
#
#                               CRASH_TYPE  ...       MOST_SEVERE_INJURY  \
# 151003            NO INJURY / DRIVE AWAY  ...  NO INDICATION OF INJURY
# 42328             NO INJURY / DRIVE AWAY  ...  NO INDICATION OF INJURY
# 158930            NO INJURY / DRIVE AWAY  ...  NO INDICATION OF INJURY
# 226793  INJURY AND / OR TOW DUE TO CRASH  ...    INCAPACITATING INJURY
# 51751             NO INJURY / DRIVE AWAY  ...  NO INDICATION OF INJURY
#
#        INJURIES_TOTAL  INJURIES_FATAL INJURIES_INCAPACITATING  CRASH_HOUR  \
# 151003            0.0             0.0                     0.0          23
# 42328             0.0             0.0                     0.0          23
# 158930            0.0             0.0                     0.0          23
# 226793            1.0             0.0                     1.0          23
# 51751             0.0             0.0                     0.0          23
#
#         CRASH_DAY_OF_WEEK  CRASH_MONTH   LATITUDE  LONGITUDE  \
# 151003                  1           12  41.762206 -87.613072
# 42328                   1           12  41.949844 -87.646875
# 158930                  1           12  41.754100 -87.583518
# 226793                  1           12  41.846412 -87.694857
# 51751                   1           12  41.928688 -87.642485
#
#                               CRASH_TIME
# 151003  ['12/31/2023', '11:50:00', 'PM']
# 42328   ['12/31/2023', '11:30:00', 'PM']
# 158930  ['12/31/2023', '11:30:00', 'PM']
# 226793  ['12/31/2023', '11:29:00', 'PM']
# 51751   ['12/31/2023', '11:25:00', 'PM']
#
# [5 rows x 23 columns]

# %%
sorted_raw_data_df.to_csv('2022-2023.csv', index=False)
